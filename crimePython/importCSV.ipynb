# %%
import pandas
crimeJan = pandas.read_csv('janCrime.csv')
crimeJan.head(30)
# Out:
#                  address  district        beat  grid  \
# 0     3108 OCCIDENTAL DR         3  3C          1115
# 1    2082 EXPEDITION WAY         5  5A          1512
# 2             4 PALEN CT         2  2A           212
# 3         22 BECKFORD CT         6  6C          1443
# 4       3421 AUBURN BLVD         2  2A           508
# 5     5301 BONNIEMAE WAY         6  6B          1084
# 6          2217 16TH AVE         4  4A           957
# 7              3547 P ST         3  3C           853
# 8       3421 AUBURN BLVD         2  2A           508
# 9      1326 HELMSMAN WAY         1  1B           444
# 10    2315 STOCKTON BLVD         6  6B          1005
# 11          5112 63RD ST         6  6B          1088
# 12     6351 DRIFTWOOD ST         4  4C          1261
# 13  7721 COLLEGE TOWN DR         3  3C           888
# 14       8460 ROVANA CIR         6  6C          1447
# 15         4856 11TH AVE         6  6B          1054
# 16          6033 69TH ST         6  6C          1403
# ...
