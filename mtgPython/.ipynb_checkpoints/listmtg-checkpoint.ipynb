# %%
import json
import pandas as pd
import requests
import sqlite3


db = sqlite3.connect("Data/MtgData.db")
df = pd.read_json(cards)
url = "https://api.scryfall.com/cards/"
data = requests.get(url).json()
cards = json.dumps(data)
pd.read_json(cards)
df = pd.DataFrame.from_records(df['data'])

df
# Out:
#     object                                    id  \
# 0     card  e8fb396f-3ae1-4705-bf94-3e1b0556e910
# 1     card  628c542b-7579-4070-9143-6f1f7221468f
# 2     card  6819b8c9-73a3-4e8e-ad7a-95cffabf873a
# 3     card  66c6d816-d9b2-4b11-b0e1-ab00be74cbda
# 4     card  60f874f9-7ac2-4d1a-97e3-722db719cd1c
# ..     ...                                   ...
# 170   card  fb132ba1-6736-40d0-ae5f-e21f19fa3bec
# 171   card  82e61900-9b5e-4032-9031-d2a531b02759
# 172   card  ba44046a-5b3f-42af-903b-cccac7758035
# 173   card  2ae4a543-f67a-464d-a875-c9aac026c5a2
# 174   card  34670558-0dbb-4fa8-a7a0-51eb4ae98aef
#
#                                 oracle_id multiverse_ids  \
# 0    3c304eaa-09e9-4439-b35d-4b05a54c2fa7             []
# 1    d82528ac-88f7-4c38-9b1c-c33e6faea532             []
# 2    eaf318f0-2cad-437c-8162-78462ecbc235             []
# 3    67f21c0c-2083-4eda-9dc3-cc8aee42289f             []
# 4    4465eff4-5851-4721-a248-866c686c2ab8             []
# ..                                    ...            ...
# 170  bdbde5d0-f5e4-44da-b27c-b4ad6f374cc9             []
# 171  695eea46-1535-48c5-bbb6-0b8379e77bfc             []
# 172  695eea46-1535-48c5-bbb6-0b8379e77bfc             []
# 173  27e0948b-9916-473b-8d8c-a51bdfbc7457             []
# 174  27e0948b-9916-473b-8d8c-a51bdfbc7457             []
#
#                            name lang released_at  \
# 0                   Acorn Stash   en  2020-02-29
# 1              Giant Teddy Bear   en  2020-02-29
# 2                        Dragon   en  2020-02-29
# 3                      Squirrel   en  2020-02-29
# 4                        Goblin   en  2020-02-29
# ..                          ...  ...         ...
# 170  Dryad of the Ilysian Grove   en  2020-01-24
# 171   Arasta of the Endless Web   en  2020-01-24
# 172   Arasta of the Endless Web   en  2020-01-24
# 173           Underworld Breach   en  2020-01-24
# 174           Underworld Breach   en  2020-01-24
#
#                                                    uri  \
# 0    https://api.scryfall.com/cards/e8fb396f-3ae1-4...
# 1    https://api.scryfall.com/cards/628c542b-7579-4...
# 2    https://api.scryfall.com/cards/6819b8c9-73a3-4...
# 3    https://api.scryfall.com/cards/66c6d816-d9b2-4...
# 4    https://api.scryfall.com/cards/60f874f9-7ac2-4...
# ..                                                 ...
# 170  https://api.scryfall.com/cards/fb132ba1-6736-4...
# 171  https://api.scryfall.com/cards/82e61900-9b5e-4...
# 172  https://api.scryfall.com/cards/ba44046a-5b3f-4...
# 173  https://api.scryfall.com/cards/2ae4a543-f67a-4...
# 174  https://api.scryfall.com/cards/34670558-0dbb-4...
#
#                                           scryfall_uri  layout  ...  \
# 0    https://scryfall.com/card/tund/6/acorn-stash?u...  normal  ...
# 1    https://scryfall.com/card/tund/5/giant-teddy-b...   token  ...
# 2    https://scryfall.com/card/tund/4/dragon?utm_so...   token  ...
# 3    https://scryfall.com/card/tund/3/squirrel?utm_...   token  ...
# 4    https://scryfall.com/card/tund/2/goblin?utm_so...   token  ...
# ..                                                 ...     ...  ...
# 170  https://scryfall.com/card/pthb/169p/dryad-of-t...  normal  ...
# 171  https://scryfall.com/card/pthb/165s/arasta-of-...  normal  ...
# 172  https://scryfall.com/card/pthb/165p/arasta-of-...  normal  ...
# 173  https://scryfall.com/card/pthb/161s/underworld...  normal  ...
# 174  https://scryfall.com/card/pthb/161p/underworld...  normal  ...
#
#      tcgplayer_id preview                                        flavor_text  \
# 0             NaN     NaN                                                NaN
# 1             NaN     NaN                                                NaN
# 2             NaN     NaN                                                NaN
# 3             NaN     NaN                                                NaN
# 4             NaN     NaN                                                NaN
# ..            ...     ...                                                ...
# 170           NaN     NaN                                                NaN
# 171           NaN     NaN  Her webs, spun from her own hair, reach from N...
# 172           NaN     NaN  Her webs, spun from her own hair, reach from N...
# 173           NaN     NaN                                                NaN
# 174           NaN     NaN                                                NaN
#
#      frame_effects card_faces watermark color_indicator loyalty  \
# 0              NaN        NaN       NaN             NaN     NaN
# 1              NaN        NaN       NaN             NaN     NaN
# 2              NaN        NaN       NaN             NaN     NaN
# 3              NaN        NaN       NaN             NaN     NaN
# 4              NaN        NaN       NaN             NaN     NaN
# ..             ...        ...       ...             ...     ...
# 170            NaN        NaN       NaN             NaN     NaN
# 171    [legendary]        NaN       NaN             NaN     NaN
# 172    [legendary]        NaN       NaN             NaN     NaN
# 173            NaN        NaN       NaN             NaN     NaN
# 174            NaN        NaN       NaN             NaN     NaN
#
#                    promo_types edhrec_rank
# 0                          NaN         NaN
# 1                          NaN         NaN
# 2                          NaN         NaN
# 3                          NaN         NaN
# 4                          NaN         NaN
# ..                         ...         ...
# 170                        NaN      3315.0
# 171  [prerelease, datestamped]      7440.0
# 172                        NaN      7440.0
# 173  [prerelease, datestamped]      5044.0
# 174                        NaN      5044.0
#
# [175 rows x 64 columns]
